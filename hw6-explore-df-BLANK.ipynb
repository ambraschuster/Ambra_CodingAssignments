# %% [markdown]
# ## Pandas - Importing data
#
# Please download the following data and move it to an appropriate folder:
#
# - <a href="https://drive.google.com/file/d/1gVDDJg3Ngnz8h9f2pX9AcdgWgx5zkV6U/view?usp=sharing">Bridge Inspections excerpt</a>.

# %%
## import the pandas library in this cell
import pandas as pd

# %% [markdown]
# ### Ingest the following dataset into this note:

# %%
## import data and store in dataframe call dfbi (short perhaps for dataframe bridge inspections)
dfbi = pd.read_csv("bridge-inspections-excerpt.csv")
dfbi
# Out:
#        STATE_CODE_001  COUNTY_CODE_003          FEATURES_DESC_006A  \
# 0                  47              189                    'BRANCH'
# 1                  47              189                    'BRANCH'
# 2                  47              189                    'BRANCH'
# 3                  47              189                  'OVERFLOW'
# 4                  47              189           'HURRICANE CREEK'
# ...               ...              ...                         ...
# 99995              53               39               'TROUT CREEK'
# 99996              53               65            'COLVILLE RIVER'
# 99997              53               77                     'DRAIN'
# 99998              53               53               'LEACH CREEK'
# 99999              53               75  'SOUTH FORK PALOUSE RIVER'
#
#           LAT_016     LONG_017  OWNER_022  FUNCTIONAL_CLASS_026  \
# 0      35595580.0   86115051.0        2.0                   8.0
# ...

# %%
## call the first 10 rows
dfbi.head(10)
# Out:
#    STATE_CODE_001  COUNTY_CODE_003 FEATURES_DESC_006A     LAT_016    LONG_017  \
# 0              47              189           'BRANCH'  35595580.0  86115051.0
# 1              47              189           'BRANCH'  35575281.0  86103402.0
# 2              47              189           'BRANCH'  36062250.0  86245507.0
# 3              47              189         'OVERFLOW'  36060931.0  86245689.0
# 4              47              189  'HURRICANE CREEK'  36031626.0  86251979.0
# 5              47              189     'PURTLE CREEK'  36000534.0  86024153.0
# 6              47              189      'GOOSE CREEK'  36035202.0  86033583.0
# 7              47              189      'GOOSE CREEK'  36033059.0  86040120.0
# 8              47              189           'BRANCH'  36014830.0  86030353.0
# 9              47              189     'PURTLE CREEK'  36004548.0  86023480.0
#
#    OWNER_022  FUNCTIONAL_CLASS_026  YEAR_BUILT_027  STRUCTURE_KIND_043A  \
# ...

# %%
## call the last 5 rows
dfbi.tail(=
# Out:
#        STATE_CODE_001  COUNTY_CODE_003          FEATURES_DESC_006A  \
# 99995              53               39               'TROUT CREEK'
# 99996              53               65            'COLVILLE RIVER'
# 99997              53               77                     'DRAIN'
# 99998              53               53               'LEACH CREEK'
# 99999              53               75  'SOUTH FORK PALOUSE RIVER'
#
#           LAT_016     LONG_017  OWNER_022  FUNCTIONAL_CLASS_026  \
# 99995  45595604.0  121314080.0        2.0                   7.0
# 99996  48103246.0  117434719.0        2.0                   7.0
# 99997  46195400.0  120161800.0        2.0                   9.0
# 99998  47122326.0  122305265.0        4.0                  14.0
# 99999  46461734.0  117141254.0        2.0                   9.0
#
#        YEAR_BUILT_027  STRUCTURE_KIND_043A  STRUCTURE_TYPE_043B DECK_COND_058  \
# 99995          1956.0                    2                  1.0             6
# ...

# %%
## call a 20 random rows
dfbi.sample(20)
# Out:
#        STATE_CODE_001  COUNTY_CODE_003         FEATURES_DESC_006A     LAT_016  \
# 36864              48               29               'LEON CREEK'  29353658.0
# 74193              50               15           'LAMOILLE RIVER'  44390391.0
# 40800              48              255        'SAN ANTONIO RIVER'  28531498.0
# 94862              53               51              'DAVIS CREEK'  48163027.0
# 70710              49               49   'UNION PACIFIC RAILROAD'  39555301.0
# 31488              48              321         'COTTONWOOD CREEK'  28590474.0
# 11771              48              359                   'US 385'  35141336.0
# 73584              49               35      'SR-68; Redwood Road'  40300232.0
# 74821              50               25             'HUNTER BROOK'  42563402.0
# 64995              48              453            'BLUE BLUFF RD'  30192492.0
# 34081              48              453           'COLORADO RIVER'  30123253.0
# ...

# %%
## get basic overview of the data
## what datatypes do the different columns hold?
## how many rows and columns are there
df.info()

## there are 99_999 rows, 16 columns with integers, strings and floating numbers (=datatypes)
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 100000 entries, 0 to 99999
# Data columns (total 16 columns):
#  #   Column                   Non-Null Count   Dtype
# ---  ------                   --------------   -----
#  0   STATE_CODE_001           100000 non-null  int64
#  1   COUNTY_CODE_003          100000 non-null  int64
#  2   FEATURES_DESC_006A       100000 non-null  str
#  3   LAT_016                  99493 non-null   float64
#  4   LONG_017                 99486 non-null   float64
#  5   OWNER_022                82621 non-null   float64
#  6   FUNCTIONAL_CLASS_026     99660 non-null   float64
#  7   YEAR_BUILT_027           99997 non-null   float64
#  8   STRUCTURE_KIND_043A      100000 non-null  int64
#  9   STRUCTURE_TYPE_043B      99999 non-null   float64
#  10  DECK_COND_058            82621 non-null   str
#  11  SUPERSTRUCTURE_COND_059  82621 non-null   str
#  12  SUBSTRUCTURE_COND_060    82621 non-null   str
#  13  CHANNEL_COND_061         82621 non-null   str
# ...

# %% [markdown]
# ### Which column has the most missing data...just a quick estimate?
# column 15, the Pier_Protection_111 column only has 4353 with data

# %%
## call the top 7 rows
dfbi.head(7)
# Out:
#    STATE_CODE_001  COUNTY_CODE_003 FEATURES_DESC_006A     LAT_016    LONG_017  \
# 0              47              189           'BRANCH'  35595580.0  86115051.0
# 1              47              189           'BRANCH'  35575281.0  86103402.0
# 2              47              189           'BRANCH'  36062250.0  86245507.0
# 3              47              189         'OVERFLOW'  36060931.0  86245689.0
# 4              47              189  'HURRICANE CREEK'  36031626.0  86251979.0
# 5              47              189     'PURTLE CREEK'  36000534.0  86024153.0
# 6              47              189      'GOOSE CREEK'  36035202.0  86033583.0
#
#    OWNER_022  FUNCTIONAL_CLASS_026  YEAR_BUILT_027  STRUCTURE_KIND_043A  \
# 0        2.0                   8.0          1965.0                    2
# 1        2.0                   8.0          1930.0                    2
# 2        2.0                   8.0          1935.0                    2
# ...

# %%
## call a sample of 10
dfbi.sample(10)
# Out:
#        STATE_CODE_001  COUNTY_CODE_003       FEATURES_DESC_006A     LAT_016  \
# 36173              48              491      'BLOCK HOUSE CREEK'  30332608.0
# 92307              51              183              'Route 646'  36485860.0
# 34226              48              453                   'DRAW'  30240999.0
# 49779              48              139  'WAXAHACHIE CREEK TRIB'  32185951.0
# 53369              48              351          'DEMPSEY CREEK'  30402526.0
# 72103              49               27            'COUNTY ROAD'  39112045.0
# 86286              51              550                 'IS 464'  36482092.0
# 34574              48              453           'WALLER CREEK'  30162095.0
# 30349              48              149     'Big Fivemile Creek'  29415095.0
# 31694              48              469                  'DRAIN'  28514529.0
#
#           LONG_017  OWNER_022  FUNCTIONAL_CLASS_026  YEAR_BUILT_027  \
# ...

# %%
## call the bottom 6
dfbi.tail(6)
# Out:
#        STATE_CODE_001  COUNTY_CODE_003          FEATURES_DESC_006A  \
# 99994              53               61               'SWAMP CREEK'
# 99995              53               39               'TROUT CREEK'
# 99996              53               65            'COLVILLE RIVER'
# 99997              53               77                     'DRAIN'
# 99998              53               53               'LEACH CREEK'
# 99999              53               75  'SOUTH FORK PALOUSE RIVER'
#
#           LAT_016     LONG_017  OWNER_022  FUNCTIONAL_CLASS_026  \
# 99994  47482979.0  122152176.0        2.0                  16.0
# 99995  45595604.0  121314080.0        2.0                   7.0
# 99996  48103246.0  117434719.0        2.0                   7.0
# 99997  46195400.0  120161800.0        2.0                   9.0
# 99998  47122326.0  122305265.0        4.0                  14.0
# 99999  46461734.0  117141254.0        2.0                   9.0
#
# ...

# %%
## call the year built column using dot notation
dfbi.YEAR_BUILT_027
# Out:
# 0        1965.0
# 1        1930.0
# 2        1935.0
# 3        1960.0
# 4        1970.0
#           ...
# 99995    1956.0
# 99996    1960.0
# 99997    1965.0
# 99998    1981.0
# 99999    1963.0
# Name: YEAR_BUILT_027, Length: 100000, dtype: float64

# %%
## call FEATURES_DESC_006A as a series using square bracket notation
dfbi["FEATURES_DESC_006A"]
# Out:
# 0                          'BRANCH'
# 1                          'BRANCH'
# 2                          'BRANCH'
# 3                        'OVERFLOW'
# 4                 'HURRICANE CREEK'
#                     ...
# 99995                 'TROUT CREEK'
# 99996              'COLVILLE RIVER'
# 99997                       'DRAIN'
# 99998                 'LEACH CREEK'
# 99999    'SOUTH FORK PALOUSE RIVER'
# Name: FEATURES_DESC_006A, Length: 100000, dtype: str

# %%
## what are the unique owner codes?
dfbi["OWNER_022"].unique()
# Out:
# array([ 2.,  4.,  1.,  3., 79., 63., 67., 64., 70., 66., 72., 74., nan,
#        68., 21., 80., 31., 32., 11., 40., 25., 26., 75., 12., 27., 55.,
#        56., 69., 62., 73., 76., 54., 77.])

# %% [markdown]
# ### What do these codes mean?

# %%
dfbi["OWNER_022"].nunique()
# Out:
# 32

# %%
##In total there a 32 different owner codes in that row that appear at least once.
